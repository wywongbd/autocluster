# %%
import os

# change working directory, run this cell once
os.chdir("../")

# %%
import numpy as np
from utils.plotting import plot_convergence, plot_convergence_average

# %load_ext autoreload
# %autoreload 2

# %%
a = [1, 2, 3, 4]
b = np.array([[1, 2], [3, 4]])
c = [[4, 1, 7, 3], [1, 7, 4], [7, 9, 1, 5, 5]]

# %%
plot_convergence(a)

# %%
plot_convergence(b, title="a", x_label="x", y_label="y", legends=["i", "j"])

# %%
plot_convergence(c, legends=["one", "two"])

# %%
plot_convergence(c, iterations='min')

# %%
plot_convergence(c, iterations=4)

# %%
d = [[1, 2, 3, 4, 5, 6], [4, 2, 3, 1], [3, 1, 3, 8, 4], [2, 4, 5, 1, 4, 6]]
line_dict = {'one' : c, 'two' : d}

# %%
plot_convergence_average(line_dict, font_color='green', x_scale='linear', area=False)

# %%
plot_convergence_average(line_dict, x_scale='log', area=True)
